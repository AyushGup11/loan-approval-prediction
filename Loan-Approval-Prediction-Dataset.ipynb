# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
train = pd.read_csv(r"D:\Data Science\Projects\Loan Prediction Dataset\train.csv")
test = pd.read_csv(r"D:\Data Science\Projects\Loan Prediction Dataset\test.csv")

# %%
if "Loan_ID" in train.columns:
    train.drop("Loan_ID", axis=1, inplace=True)
    train.drop("Loan_ID", axis=1, inplace=True)

# %%
for col in train.columns:
    if train[col].dtype == "object":
        train[col].fillna(train[col].mode()[0], inplace=True)
        test[col].fillna(test[col].mode()[0], inplace=True)
    else:
        train[col].fillna(train[col].median(), inplace=True)
        test[col].fillna(test[col].median(), inplace=True)
# Out:
# C:\Users\Ayush\AppData\Local\Temp\ipykernel_22540\1701822797.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train[col].fillna(train[col].median(), inplace=True)
# C:\Users\Ayush\AppData\Local\Temp\ipykernel_22540\1701822797.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
le = LabelEncoder()

for col in train.columns:
    if train[col].dtype == "object":
       train[col]= le.fit_transform(train[col])
       test[col]= le.transform(test[col])

# %%
x = train.drop(" loan_status", axis=1)
y = train[" loan_status"]

x_train, x_val, y_train, y_val = train_test_split( x, y, test_size=0.2, random_state=42)

# %%
model = RandomForestClassifier(random_state=42)
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = model.predict(x_val)

print("Accuracy:", accuracy_score(y_val, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_val, y_pred))
print("\nClassification Report:\n", classification_report(y_val, y_pred))
# Out:
# Accuracy: 0.9824304538799414
#
# Confusion Matrix:
#  [[426   2]
#  [ 10 245]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       428
#            1       0.99      0.96      0.98       255
#
#     accuracy                           0.98       683
#    macro avg       0.98      0.98      0.98       683
# weighted avg       0.98      0.98      0.98       683

# %%
model.fit(x,y)
# Out:
# RandomForestClassifier(random_state=42)

# %%
test_features = test.drop(' loan_status', axis=1)  # Remove the target column

test_predictions = model.predict(test_features)

# %%
if " loan_status" in test.columns:
    test = test.drop(" loan_status", axis=1)

test_predictions = model.predict(test)

# %%
submission = pd.DataFrame({
    " loan_status": test_predictions
})

submission.to_csv("submission.csv", index=False)

print("Submission file created sucessfully!!")
# Out:
# Submission file created sucessfully!!
